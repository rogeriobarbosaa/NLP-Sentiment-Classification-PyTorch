# %%
import os
import torch
import pandas as pd
from torch import nn
from torch.utils.data import DataLoader, TensorDataset

# %%
os.chdir("../")

# %%
from src.LSTM import LSTM

# %% [markdown]
# ### Treinamento
#
# Pipeline de Treino:
# 1. Modelo
# 2. Loss e Otimizador
# 3. Loop de Treino:
#     - Forward Pass
#     - Calcula Loss
#     - Backward Pass
#     - Atualiza Pesos

# %% [markdown]
# ### 0. Preparação

# %%
X_train = torch.load("data/X_train.pt")
y_train = torch.load("data/y_train.pt")

# %%
dataset = TensorDataset(X_train, y_train)
dataset

# %%
train_loader = DataLoader(dataset=dataset, batch_size=30, shuffle=True)
train_loader

# %% [markdown]
# ### 1. Modelo

# %%
input_size = 100
hidden_size = 5
num_layers = 2
num_classes = 3

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes)

# %% [markdown]
# ### 2. Loss e Otimizador

# %%
learning_rate = 0.002

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

# %% [markdown]
# ### 3. Treinamento

# %%
num_epochs = 50

# %%
for epoch in range(num_epochs):
    epoch_loss = 0

    for i, (batch_feat, batch_label) in enumerate(train_loader):  # itera a cada batch
        # Forward pass
        y_pred = model(batch_feat)  # previsões do batch atual

        # Calcula loss
        loss = criterion(y_pred, batch_label)  # loss do batch atual
        epoch_loss += loss

        # Backward pass
        loss.backward()

        # Updates
        optimizer.step()  # atualiza o otimizador
        optimizer.zero_grad()

    print(f"Epoch: {epoch+1} | Loss = {epoch_loss/(i+1)}")
# Out:
# Epoch: 1 | Loss = 1.0767602920532227
# Epoch: 2 | Loss = 1.0474435091018677
# Epoch: 3 | Loss = 1.0374855995178223
# Epoch: 4 | Loss = 1.0310419797897339
# Epoch: 5 | Loss = 1.0266497135162354
# Epoch: 6 | Loss = 1.0252189636230469
# Epoch: 7 | Loss = 1.0206365585327148
# Epoch: 8 | Loss = 1.0195972919464111
# Epoch: 9 | Loss = 1.0166115760803223
# Epoch: 10 | Loss = 1.0143967866897583
# Epoch: 11 | Loss = 1.0138909816741943
# Epoch: 12 | Loss = 1.011886477470398
# Epoch: 13 | Loss = 1.0104560852050781
# Epoch: 14 | Loss = 1.0086593627929688
# Epoch: 15 | Loss = 1.0072616338729858
# Epoch: 16 | Loss = 1.007041573524475
# Epoch: 17 | Loss = 1.0052802562713623
# Epoch: 18 | Loss = 1.0052216053009033
# Epoch: 19 | Loss = 1.0043981075286865
# Epoch: 20 | Loss = 1.005423903465271
# Epoch: 21 | Loss = 1.0036108493804932
# Epoch: 22 | Loss = 1.0028038024902344
# Epoch: 23 | Loss = 1.0022050142288208
# Epoch: 24 | Loss = 1.001962423324585
# Epoch: 25 | Loss = 1.0015971660614014
# Epoch: 26 | Loss = 1.0016671419143677
# Epoch: 27 | Loss = 1.0001813173294067
# Epoch: 28 | Loss = 0.9999066591262817
# Epoch: 29 | Loss = 0.9979966878890991
# Epoch: 30 | Loss = 0.9989128708839417
# Epoch: 31 | Loss = 0.9985273480415344
# Epoch: 32 | Loss = 0.9968929290771484
# Epoch: 33 | Loss = 0.9976256489753723
# Epoch: 34 | Loss = 0.9962295293807983
# Epoch: 35 | Loss = 0.9966777563095093
# Epoch: 36 | Loss = 0.9958291053771973
# Epoch: 37 | Loss = 0.9960722327232361
# Epoch: 38 | Loss = 0.9952877759933472
# Epoch: 39 | Loss = 0.9947218298912048
# Epoch: 40 | Loss = 0.995451033115387
# Epoch: 41 | Loss = 0.994603157043457
# Epoch: 42 | Loss = 0.9939990043640137
# Epoch: 43 | Loss = 0.9947335124015808
# Epoch: 44 | Loss = 0.9929695129394531
# Epoch: 45 | Loss = 0.9936254024505615
# Epoch: 46 | Loss = 0.993962287902832
# Epoch: 47 | Loss = 0.9916924238204956
# Epoch: 48 | Loss = 0.9917141199111938
# Epoch: 49 | Loss = 0.9921035170555115
# Epoch: 50 | Loss = 0.9918218851089478

# %% [markdown]
# ### Salvando o modelo

# %%
torch.save(model, 'data/model.pth')
