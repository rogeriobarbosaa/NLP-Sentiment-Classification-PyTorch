# %%
import os
import torch
import pandas as pd
from torch.utils.data import DataLoader, ConcatDataset

# %%
os.chdir("../")

# %% [markdown]
# ### Treinamento
#
# Pipeline de Treino:
# 1. Modelo
# 2. Loss e Otimizador
# 3. Loop de Treino:
#     - Forward Pass
#     - Calcula Loss
#     - Backward Pass
#     - Atualiza Pesos

# %% [markdown]
# ### 0. Preparação

# %%
X_train = pd.read_csv("data/X_train.csv")
y_train = pd.read_csv("data/y_train.csv")

# %%
dataset = ConcatDataset([X_train, y_train])
dataset

# %%
train_loader = DataLoader(dataset=dataset, batch_size=30, shuffle=True)
train_loader
